# %%
#My project is based on providing valuable insights to my client MTA on turnstile jumping,
#to influence their decision making on increasing their security(increase height of turnstile) or 
#re-direct MTA security to locations, where the rules are breached to an enormous extend.

# %%
#For this project, I've shortlisted Canal Street based on highest negative entries (Exits more than entries) on the sample dataset analyzed
#Also, it a residential area and I'm dropping tourist location as it can possibly distort my analysis.
#My suggested subway station/stations will be further monitored by MTA employees via CCTV cameras and 
# if the investigations concludes that a sizeable revenue is lost, they will act as they deem appropriate.

# %%
#Assumptions: 
#1) Turnstiles are functional.
#2)People in residential areas commute to and fro from the same subway stations everytime.
#3) Most travel from subway stations in residential areas is for work and academics.
#4) People don't exit from the emergency gate.

# %%
#I've plotted the entries and exits from Canal street, which has the highest difference in terms of negative entries

# %%
from IPython.display import Image

PATH = "C:/Users/reyno/OneDrive/Desktop/Metis/"
Image(filename = PATH + "Canal st.png", width=1000, height=500)
